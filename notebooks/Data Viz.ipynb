# %%
import matplotlib.pyplot as plt
import seaborn as sns
x=np.linspace(0,10,100)

# %% [markdown]
# ### Cycle de vie d'une figure

# %%
plt.figure(figsize=(12,8))
plt.plot(x,x**2,label='x²')
plt.plot(x,x**2.3+5,label='x**2.3+5')
plt.xlabel('x')
plt.ylabel('f (x)')
plt.legend()
plt.grid()
